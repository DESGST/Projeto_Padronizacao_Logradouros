# %%
from buscaEndereco_CET_v12_0 import (
    buscar_endereco_com_coordenadas,   # ← Nova: substitui buscar_endereco_candidatos
    buscar_endereco_completo,          # ← Nova: substitui buscar_endereco_enriquecido.
    enriquecer_candidatos_geoserver    # ← Nova: enriquecimento separado
)

# %%
buscar_endereco_completo('RUA DOUTOR LUIS AIRES',1364,-23.5375,-46.487).head(25)
# Out:
# 2025-11-19 11:31:49,389 - INFO - 🔍 Buscando: 'RUA DOUTOR LUIS AIRES', Número: '1364'
# 2025-11-19 11:31:49,559 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:31:49,659 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:31:49,661 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:31:51,607 - INFO - 🔍 Executando embedding para: 'RUA DOUTOR LUIS AIRES'
# 2025-11-19 11:31:51,607 - INFO - 🔨 Carregando modelo em memória...
# 2025-11-19 11:32:00,657 - INFO - ✅ Modelo carregado em 9.05 segundos
# 2025-11-19 11:32:00,748 - INFO - ✅ 7 candidatos em 9.141 segundos
# 2025-11-19 11:32:00,749 - INFO - 📊 Embedding retornou 7 candidatos iniciais
# 2025-11-19 11:32:06,741 - INFO - 🎯 Embedding: 7 resultados válidos processados
# 2025-11-19 11:32:06,741 - INFO - 🎯 Filtro embedding: 5 resultados relevantes
# 2025-11-19 11:32:06,741 - INFO - 🎯 Fallback: encontrado 5 resultado(s) do tipo 'RUA'
# 2025-11-19 11:32:06,755 - INFO - 🎯 Embedding: priorizando resultados do tipo 'RUA'
# 2025-11-19 11:32:06,755 - INFO - ✅ Embedding trouxe 5 resultados relevantes
# 2025-11-19 11:32:06,761 - INFO - ✅ Resultado final combinado: 5 candidatos
#   codlog            logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  12156            R DR LUIZ AYRES        -23.536678         -46.487286
# 2  02633                R DOS AIRES        -23.595366         -46.541067
# 3  15711      R DR PAULO AIRES NETO        -23.654265         -46.680679
# 4  11115       R DR JOSE AIRES NETO        -23.580949         -46.735792
# 5  02646  R DR AIRES MARTINS TORRES        -23.558640         -46.760382
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB Distrito_Nome  \
# 1         0.096         100.0    EMBEDDING  LE  LE3  PE   ARTUR ALVIM
# 2         8.472          64.0    EMBEDDING  SE  SE1  VP     SAO LUCAS
# 3        23.623          63.0    EMBEDDING  SU  SU3  SA  CAMPO GRANDE
# 4        25.815          67.0    EMBEDDING  OE  OE2  BT       BUTANTA
# 5        27.966          64.0    EMBEDDING  OE  OE2  BT   RIO PEQUENO
#
#   Regiao_Nome Classificacao
# 1       Leste      ARTERIAL
# 2       Leste         LOCAL
# 3         Sul         LOCAL
# 4       Oeste         LOCAL
# 5       Oeste      COLETORA

# %%
buscar_endereco_completo('RUA DOUTOR LUIS AIRES',100,-23.5322045,-46.5007899).head(25)
# Out:
# 2025-11-19 11:32:08,976 - INFO - 🔍 Buscando: 'RUA DOUTOR LUIS AIRES', Número: '100'
# 2025-11-19 11:32:09,073 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:32:09,138 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:32:09,138 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:32:09,139 - INFO - 🔍 Executando embedding para: 'RUA DOUTOR LUIS AIRES'
# 2025-11-19 11:32:09,200 - INFO - 📊 Embedding retornou 7 candidatos iniciais
# 2025-11-19 11:32:13,064 - INFO - 🎯 Embedding: 7 resultados válidos processados
# 2025-11-19 11:32:13,070 - INFO - 🎯 Filtro embedding: 5 resultados relevantes
# 2025-11-19 11:32:13,072 - INFO - 🎯 Fallback: encontrado 5 resultado(s) do tipo 'RUA'
# 2025-11-19 11:32:13,073 - INFO - 🎯 Embedding: priorizando resultados do tipo 'RUA'
# 2025-11-19 11:32:13,073 - INFO - ✅ Embedding trouxe 5 resultados relevantes
# 2025-11-19 11:32:13,077 - INFO - ✅ Resultado final combinado: 5 candidatos
#   codlog            logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  12156            R DR LUIZ AYRES        -23.532120         -46.500613
# 2  02633                R DOS AIRES        -23.594483         -46.541953
# 3  15711      R DR PAULO AIRES NETO        -23.653520         -46.681024
# 4  11115       R DR JOSE AIRES NETO        -23.582022         -46.737173
# 5  02646  R DR AIRES MARTINS TORRES        -23.554884         -46.757277
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB Distrito_Nome  \
# 1         0.020         100.0    EMBEDDING  LE  LE3  PE   ARTUR ALVIM
# 2         8.097          64.0    EMBEDDING  SE  SE1  VP     SAO LUCAS
# 3        22.788          63.0    EMBEDDING  SU  SU3  SA  CAMPO GRANDE
# 4        24.723          67.0    EMBEDDING  OE  OE2  BT       BUTANTA
# 5        26.267          64.0    EMBEDDING  OE  OE2  BT   RIO PEQUENO
#
#   Regiao_Nome Classificacao
# 1       Leste      ARTERIAL
# 2       Leste         LOCAL
# 3         Sul         LOCAL
# 4       Oeste         LOCAL
# 5       Oeste         LOCAL

# %%
buscar_endereco_completo('RUA EDISON',640,-23.6215138,-46.6766455).head(25)
# Out:
# 2025-11-19 11:32:15,199 - INFO - 🎯 VIA PROBLEMÁTICA DETECTADA: 'RUA EDISON' - usando APENAS embedding
# 2025-11-19 11:32:15,199 - INFO - 🔍 Executando embedding para: 'RUA EDISON'
# 2025-11-19 11:32:15,278 - INFO - 📊 Embedding retornou 6 candidatos iniciais
# 2025-11-19 11:32:20,269 - INFO - 🎯 Embedding: 6 resultados válidos processados
# 2025-11-19 11:32:20,273 - INFO - ✅ Embedding para 'RUA EDISON' trouxe 6 resultados
#   codlog                   logradouro_PMSP  latitude_geocode  \
# 0  06191                           R EDSON        -23.621257
# 2  30355                 R DR EDISON GOMES        -23.569895
# 3  18908                  AV THOMAS EDISON        -23.519642
# 4  37731         PC EDISON RODRIGUES SOUZA        -23.598623
# 1  42534              PC EDISON DOS SANTOS        -23.501540
# 5  27315  TV EDISON CARLOS CORREA DE MELLO        -23.510147
#
#    longitude_geocode  distancia_km  similaridade _fonte_busca GET  DET SUB  \
# 0         -46.676384         0.039           100    EMBEDDING  SO  SO1  SA
# 2         -46.772623        11.340            74    EMBEDDING  OE  OE2  BT
# 3         -46.668533        11.358            65    EMBEDDING  NO  NO2  LA
# 4         -46.516103        16.554            63    EMBEDDING  SE  SE1  SP
# 1         -46.495867        22.748            74    EMBEDDING  LE  LE3  PE
# 5         -46.421948        28.762            57    EMBEDDING  LE  LE2  IT
#
#   Distrito_Nome Regiao_Nome Classificacao
# 0    CAMPO BELO         Sul         LOCAL
# 2   RIO PEQUENO       Oeste      COLETORA
# 3   BARRA FUNDA       Oeste      COLETORA
# 4     SAPOPEMBA       Leste         LOCAL
# 1      CANGAIBA       Leste         LOCAL
# 5   VILA CURUCA       Leste      COLETORA

# %%
buscar_endereco_completo('SPEERS',738,-23.5181108,-46.701804).head(25)
# Out:
# 2025-11-19 11:32:23,706 - INFO - 🎯 VIA PROBLEMÁTICA DETECTADA: 'SPEERS' - usando APENAS embedding
# 2025-11-19 11:32:23,707 - INFO - 🔍 Executando embedding para: 'SPEERS'
# 2025-11-19 11:32:23,786 - INFO - 📊 Embedding retornou 4 candidatos iniciais
# 2025-11-19 11:32:25,050 - INFO - 🎯 Embedding: 4 resultados válidos processados
# 2025-11-19 11:32:25,052 - INFO - ✅ Embedding para 'SPEERS' trouxe 4 resultados
#   codlog        logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 3  19951       R WILLIAM SPEERS        -23.518271         -46.701869
# 0  18916         R TOMAS SPEERS        -23.516812         -46.594147
# 2  19860  R DONA VITORIA SPEERS        -23.568466         -46.553413
# 1  35942          R JOHN SPEERS        -23.571863         -46.458566
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB    Distrito_Nome  \
# 3         0.019            75    EMBEDDING  NO  NO1  LA             LAPA
# 0        10.978            85    EMBEDDING  CN  CN2  MG       VILA MARIA
# 2        16.130            77    EMBEDDING  SE  SE1  AF     VILA FORMOSA
# 1        25.505            80    EMBEDDING  SE  SE3  IQ  PARQUE DO CARMO
#
#   Regiao_Nome Classificacao
# 3       Oeste      COLETORA
# 0       Norte         LOCAL
# 2       Leste      COLETORA
# 1       Leste      COLETORA

# %%
# Teste 1 - Verificar se a função está sendo chamada
#result1 
buscar_endereco_com_coordenadas('SP 070', '15', -23.5, -46.6)
# Out:
# 2025-11-19 11:32:27,097 - INFO - 🔍 Buscando: 'SP 070', Número: '15'
# 2025-11-19 11:32:27,097 - INFO - 🎯 Rodovia especial detectada: AYRTON SENNA - forçando busca especial
# 2025-11-19 11:32:27,098 - INFO - 🛣️  Buscando rodovia especial 'AYRTON SENNA' em 12 vias
# 2025-11-19 11:32:27,292 - INFO - 🛣️  RV AYRTON SENNA: KM 15.0 → Metro 15000
# 2025-11-19 11:32:27,879 - INFO - 🛣️  RV DOS TRABALHADORES: KM 15.0 → Metro 15000
# 2025-11-19 11:32:28,691 - INFO - ✅ Rodovia especial 'AYRTON SENNA': 2 resultados RODOVIÁRIOS encontrados
# 2025-11-19 11:32:28,695 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  42369      RV DOS TRABALHADORES        -23.507448         -46.549406
# 0  Z1833  RV AYRTON SENNA DA SILVA        -23.480889         -46.453080
#
#    distancia_km    _fonte_busca
# 1         5.225  VIAS_COMPLEXAS
# 0        15.133  VIAS_COMPLEXAS

# %%
# Teste 2 - Verificar com número explícito
#result2
buscar_endereco_com_coordenadas('SP 070', '5', -23.5, -46.6)
# Out:
# 2025-11-19 11:32:28,705 - INFO - 🔍 Buscando: 'SP 070', Número: '5'
# 2025-11-19 11:32:28,705 - INFO - 🎯 Rodovia especial detectada: AYRTON SENNA - forçando busca especial
# 2025-11-19 11:32:28,705 - INFO - 🛣️  Buscando rodovia especial 'AYRTON SENNA' em 12 vias
# 2025-11-19 11:32:28,902 - INFO - 🛣️  RV AYRTON SENNA: KM 5.0 → Metro 5000
# 2025-11-19 11:32:29,543 - INFO - 🛣️  RV DOS TRABALHADORES: KM 5.0 → Metro 5000
# 2025-11-19 11:32:29,917 - INFO - ✅ Rodovia especial 'AYRTON SENNA': 2 resultados RODOVIÁRIOS encontrados
# 2025-11-19 11:32:29,921 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  42369      RV DOS TRABALHADORES        -23.496776         -46.543329
# 0  Z1833  RV AYRTON SENNA DA SILVA        -23.480889         -46.453080
#
#    distancia_km    _fonte_busca
# 1         5.790  VIAS_COMPLEXAS
# 0        15.133  VIAS_COMPLEXAS

# %%
buscar_endereco_com_coordenadas('RUA ORIENTE',749,-23.5376434,-46.6148791).head(25)
# Out:
# 2025-11-19 11:32:29,932 - INFO - 🔍 Buscando: 'RUA ORIENTE', Número: '749'
# 2025-11-19 11:32:29,985 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:30,330 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  15053       R ORIENTE        -23.538037         -46.621307         0.657
#
#    similaridade _fonte_busca
# 0           100        EXATO

# %%
buscar_endereco_com_coordenadas('TUNEL 9 DE JULHO',	100,	-23.5623415,	-46.6561352).head(25)
# Out:
# 2025-11-19 11:32:30,343 - INFO - 🔤 Normalização numérica: 'TUNEL 9 DE JULHO' -> 'TUNEL NOVE DE JULHO'
# 2025-11-19 11:32:30,344 - INFO - 🔤 Endereço normalizado: 'TUNEL 9 DE JULHO' → 'TUNEL NOVE DE JULHO'
# 2025-11-19 11:32:30,345 - INFO - 🔍 Buscando: 'TUNEL NOVE DE JULHO', Número: '100'
# 2025-11-19 11:32:30,484 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:32:30,485 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:32:30,486 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:32:30,486 - INFO - 🔍 Executando embedding para: 'TUNEL NOVE DE JULHO'
# 2025-11-19 11:32:30,567 - INFO - 📊 Embedding retornou 9 candidatos iniciais
# 2025-11-19 11:32:34,846 - INFO - 🎯 Embedding: 8 resultados válidos processados
# 2025-11-19 11:32:34,851 - INFO - 🎯 Filtro embedding: 8 resultados relevantes
# 2025-11-19 11:32:34,852 - INFO - ✅ Embedding trouxe 8 resultados relevantes
# 2025-11-19 11:32:34,856 - INFO - ✅ Resultado final combinado: 8 candidatos
#   codlog                      logradouro_PMSP  latitude_geocode  \
# 1  48365                TN DAHER ELIAS CUTAIT        -23.561363
# 2  14810                     VD NOVE DE JULHO        -23.548915
# 3  14804                     AV NOVE DE JULHO        -23.548878
# 4  14806                      R NOVE DE JULHO        -23.644345
# 5  51955              PC JARDIM NOVE DE JULHO        -23.590600
# 6  50241                     PQ NOVE DE JULHO        -23.720791
# 7  Z5155             R NOVE DE JULHO (GRAJAU)        -23.762502
# 8  Z5272  R VINTE E NOVE DE JULHO (JD HELENA)        -23.483469
#
#    longitude_geocode  distancia_km  similaridade _fonte_busca
# 1         -46.655750         0.116         100.0    EMBEDDING
# 2         -46.642384         2.048          63.0    EMBEDDING
# 3         -46.639911         2.231          69.0    EMBEDDING
# 4         -46.700333        10.170          79.0    EMBEDDING
# 5         -46.483237        17.899          60.0    EMBEDDING
# 6         -46.708871        18.420          66.0    EMBEDDING
# 7         -46.686402        22.469          79.0    EMBEDDING
# 8         -46.415751        26.030          66.0    EMBEDDING

# %%
buscar_endereco_com_coordenadas('RUA 24 DE MAIO',	166,	-23.5438105,	-46.6398333).head(25)
# Out:
# 2025-11-19 11:32:34,868 - INFO - 🔤 Normalização numérica: 'RUA 24 DE MAIO' -> 'RUA VINTE E QUATRO DE MAIO'
# 2025-11-19 11:32:34,868 - INFO - 🔤 Endereço normalizado: 'RUA 24 DE MAIO' → 'RUA VINTE E QUATRO DE MAIO'
# 2025-11-19 11:32:34,868 - INFO - 🔍 Buscando: 'RUA VINTE E QUATRO DE MAIO', Número: '166'
# 2025-11-19 11:32:34,919 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:35,243 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  19759  R VINTE E QUATRO DE MAIO        -23.544042         -46.639877
#
#    distancia_km  similaridade _fonte_busca
# 0         0.026           100        EXATO

# %%
buscar_endereco_com_coordenadas('JACEGUAVA',	863,	-23.77082474,	-46.73260551).head(25)
# Out:
# 2025-11-19 11:32:35,256 - INFO - 🔍 Buscando: 'JACEGUAVA', Número: '863'
# 2025-11-19 11:32:35,299 - INFO - ✅ 2 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:36,110 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog  logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  41808     AV JACEGUAVA        -23.774061         -46.730031         0.445
# 1  41809  ES DO JACEGUAVA        -23.787759         -46.773775         4.593
#
#    similaridade _fonte_busca
# 0           100        EXATO
# 1           100        EXATO

# %%
buscar_endereco_com_coordenadas('DO JACEGUAVA',	863,	-23.77082474,	-46.73260551).head(25)
# Out:
# 2025-11-19 11:32:36,140 - INFO - 🔄 Variações de busca: ['DO JACEGUAVA', 'JACEGUAVA']
# 2025-11-19 11:32:36,141 - INFO - 🔍 Buscando: 'DO JACEGUAVA', Número: '863'
# 2025-11-19 11:32:36,187 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:36,730 - INFO - ✅ 2 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:37,750 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog  logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 1  41808     AV JACEGUAVA        -23.774061         -46.730031         0.445
# 0  41809  ES DO JACEGUAVA        -23.787759         -46.773775         4.593
#
#    similaridade _fonte_busca
# 1           100        EXATO
# 0           100        EXATO

# %%
buscar_endereco_com_coordenadas('AVENIDA DO JACEGUAVA',	863,	-23.77082474,	-46.73260551).head(25)
# Out:
# 2025-11-19 11:32:37,763 - INFO - 🔍 Buscando: 'AVENIDA DO JACEGUAVA', Número: '863'
# 2025-11-19 11:32:37,993 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:32:38,019 - INFO - ✅ 2 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:38,881 - INFO - 🎯 Fallback: encontrado 1 resultado(s) do tipo 'AVENIDA'
# 2025-11-19 11:32:38,881 - INFO - 🎯 Fallback: priorizando resultados do tipo 'AVENIDA'
# 2025-11-19 11:32:38,883 - INFO - ✅ Fallback sem tipo de via trouxe 1 resultados relevantes
# 2025-11-19 11:32:38,884 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:32:38,889 - INFO - ✅ Resultado final combinado: 1 candidatos
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 1  41808    AV JACEGUAVA        -23.774061         -46.730031         0.445
#
#    similaridade    _fonte_busca
# 1          90.0  EXATO_SEM_TIPO

# %%
buscar_endereco_com_coordenadas('SP 021',103,-23.8039357,-46.7051759).head(25)
# Out:
# 2025-11-19 11:32:38,900 - INFO - 🔍 Buscando: 'SP 021', Número: '103'
# 2025-11-19 11:32:38,904 - INFO - 🎯 Nome de rodovia detectado: 'SP 021' - buscando APENAS como rodovia
# 2025-11-19 11:32:38,904 - INFO - 🛣️  Buscando rodovia SP 021 pelo código 51501
# 2025-11-19 11:32:38,932 - INFO - 🛣️  RV MARIO COVAS: KM 103.0 → Metro 103000
# 2025-11-19 11:32:39,498 - INFO - ✅ Rodovia SP 021 encontrada: RV MARIO COVAS
# 2025-11-19 11:32:39,500 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  51501  RV MARIO COVAS        -23.451667         -46.786858        40.045
#
#    similaridade _fonte_busca
# 0           100      RODOVIA

# %%
buscar_endereco_com_coordenadas('SP 021',99,-23.8039357,-46.7051759).head(25)
# Out:
# 2025-11-19 11:32:39,510 - INFO - 🔍 Buscando: 'SP 021', Número: '99'
# 2025-11-19 11:32:39,510 - INFO - 🎯 Nome de rodovia detectado: 'SP 021' - buscando APENAS como rodovia
# 2025-11-19 11:32:39,511 - INFO - 🛣️  Buscando rodovia SP 021 pelo código 51501
# 2025-11-19 11:32:39,546 - INFO - 🛣️  RV MARIO COVAS: KM 99.0 → Metro 99000
# 2025-11-19 11:32:40,399 - INFO - ✅ Rodovia SP 021 encontrada: RV MARIO COVAS
# 2025-11-19 11:32:40,399 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  51501  RV MARIO COVAS        -23.451667         -46.786858        40.045
#
#    similaridade _fonte_busca
# 0           100      RODOVIA

# %%
buscar_endereco_com_coordenadas('SP 270',12,-23.5571019,-46.6701834).head(25)
# Out:
# 2025-11-19 11:32:40,410 - INFO - 🔍 Buscando: 'SP 270', Número: '12'
# 2025-11-19 11:32:40,410 - INFO - 🎯 Nome de rodovia detectado: 'SP 270' - buscando APENAS como rodovia
# 2025-11-19 11:32:40,415 - INFO - 🛣️  Buscando rodovia SP 270 pelo código 16878
# 2025-11-19 11:32:40,447 - INFO - 🛣️  VIA RAPOSO TAVARES: KM 12.0 → Metro 12000
# 2025-11-19 11:32:41,143 - INFO - ✅ Rodovia SP 270 encontrada: VIA RAPOSO TAVARES
# 2025-11-19 11:32:41,146 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog     logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  16878  VIA RAPOSO TAVARES        -23.585967         -46.760441
#
#    distancia_km  similaridade _fonte_busca
# 0         9.743           100      RODOVIA

# %%
buscar_endereco_com_coordenadas('AVENIDA 23 DE MAIO',11,-23.5691774,-46.64089).head(25)
# Out:
# 2025-11-19 11:32:41,153 - INFO - 🔍 Buscando: 'AVENIDA 23 DE MAIO', Número: '11'
# 2025-11-19 11:32:41,203 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:41,996 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog          logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  19764  AV VINTE E TRES DE MAIO        -23.549724         -46.638613
#
#    distancia_km  similaridade _fonte_busca
# 0         2.176           100        EXATO

# %%
buscar_endereco_com_coordenadas('AVENIDA 23 DE MAIO',11000,-23.5691774,-46.64089).head(25)
#não melhoria considerar Km
# Out:
# 2025-11-19 11:32:42,007 - INFO - 🔍 Buscando: 'AVENIDA 23 DE MAIO', Número: '11000'
# 2025-11-19 11:32:42,061 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:42,762 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog          logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  19764  AV VINTE E TRES DE MAIO        -23.591188         -46.651208
#
#    distancia_km  similaridade _fonte_busca
# 0         2.664           100        EXATO

# %%
buscar_endereco_completo('SP 070',	15,	-23.49652885,	-46.52947422).head(25)
# Out:
# 2025-11-19 11:32:42,772 - INFO - 🔍 Buscando: 'SP 070', Número: '15'
# 2025-11-19 11:32:42,773 - INFO - 🎯 Rodovia especial detectada: AYRTON SENNA - forçando busca especial
# 2025-11-19 11:32:42,773 - INFO - 🛣️  Buscando rodovia especial 'AYRTON SENNA' em 12 vias
# 2025-11-19 11:32:42,944 - INFO - 🛣️  RV AYRTON SENNA: KM 15.0 → Metro 15000
# 2025-11-19 11:32:43,639 - INFO - 🛣️  RV DOS TRABALHADORES: KM 15.0 → Metro 15000
# 2025-11-19 11:32:44,351 - INFO - ✅ Rodovia especial 'AYRTON SENNA': 2 resultados RODOVIÁRIOS encontrados
# 2025-11-19 11:32:44,351 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  42369      RV DOS TRABALHADORES        -23.507448         -46.549406
# 0  Z1833  RV AYRTON SENNA DA SILVA        -23.480889         -46.453080
#
#    distancia_km    _fonte_busca   GET   DET   SUB Distrito_Nome Regiao_Nome  \
# 1         2.368  VIAS_COMPLEXAS    MB    TT    PE      CANGAIBA       Leste
# 0         7.982  VIAS_COMPLEXAS  None  None  None          None        None
#
#   Classificacao
# 1      ARTERIAL
# 0      ARTERIAL

# %%
buscar_endereco_completo('SP 070',	15,	-23.49652885,	-46.52947422).head(25)
# Out:
# 2025-11-19 11:32:44,933 - INFO - 🔍 Buscando: 'SP 070', Número: '15'
# 2025-11-19 11:32:44,934 - INFO - 🎯 Rodovia especial detectada: AYRTON SENNA - forçando busca especial
# 2025-11-19 11:32:44,935 - INFO - 🛣️  Buscando rodovia especial 'AYRTON SENNA' em 12 vias
# 2025-11-19 11:32:45,109 - INFO - 🛣️  RV AYRTON SENNA: KM 15.0 → Metro 15000
# 2025-11-19 11:32:46,055 - INFO - 🛣️  RV DOS TRABALHADORES: KM 15.0 → Metro 15000
# 2025-11-19 11:32:46,851 - INFO - ✅ Rodovia especial 'AYRTON SENNA': 2 resultados RODOVIÁRIOS encontrados
# 2025-11-19 11:32:46,870 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  42369      RV DOS TRABALHADORES        -23.507448         -46.549406
# 0  Z1833  RV AYRTON SENNA DA SILVA        -23.480889         -46.453080
#
#    distancia_km    _fonte_busca   GET   DET   SUB Distrito_Nome Regiao_Nome  \
# 1         2.368  VIAS_COMPLEXAS    MB    TT    PE      CANGAIBA       Leste
# 0         7.982  VIAS_COMPLEXAS  None  None  None          None        None
#
#   Classificacao
# 1      ARTERIAL
# 0      ARTERIAL

# %%
buscar_endereco_completo('ayrton senna',	15000,	-23.49652885,	-46.52947422).head(25)
# Out:
# 2025-11-19 11:32:49,670 - INFO - 🔍 Buscando: 'ayrton senna', Número: '15000'
# 2025-11-19 11:32:49,671 - INFO - 🎯 Nome de rodovia detectado: 'AYRTON SENNA' - buscando APENAS como rodovia
# 2025-11-19 11:32:50,459 - INFO - ✅ Rodovia 'AYRTON SENNA' encontrada: RV DOS TRABALHADORES
# 2025-11-19 11:32:50,460 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog       logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  42369  RV DOS TRABALHADORES        -23.507448         -46.549406
#
#    distancia_km  similaridade _fonte_busca GET DET SUB Distrito_Nome  \
# 0         2.368           100      RODOVIA  MB  TT  PE      CANGAIBA
#
#   Regiao_Nome Classificacao
# 0       Leste      ARTERIAL

# %%
buscar_endereco_completo('R PINHEIRO DE LEMOS',28,-23.600861,-46.595778).head(25)
# Out:
# 2025-11-19 11:32:50,768 - INFO - 🔍 Buscando: 'R PINHEIRO DE LEMOS', Número: '28'
# 2025-11-19 11:32:50,798 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:51,077 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog      logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  16267  R PINHEIRO DE LEMOS        -23.600844         -46.595694
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB Distrito_Nome  \
# 0         0.009           100        EXATO  SE  SE2  IP      IPIRANGA
#
#   Regiao_Nome Classificacao
# 0         Sul      COLETORA

# %%
buscar_endereco_completo('RUA DAS JUNTAS PROVISORIAS',280,-23.5894924,-46.5984088).head(25)
# Out:
# 2025-11-19 11:32:51,540 - INFO - 🔍 Buscando: 'RUA DAS JUNTAS PROVISORIAS', Número: '280'
# 2025-11-19 11:32:51,557 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:51,755 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  11379  R DAS JUNTAS PROVISORIAS        -23.588958         -46.598202
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB Distrito_Nome  \
# 0         0.063           100        EXATO  MB  SE2  IP      IPIRANGA
#
#   Regiao_Nome Classificacao
# 0         Sul      ARTERIAL

# %%
buscar_endereco_com_coordenadas('DE ITAPECERICA',3421,-23.65627152,-46.76275546).head(25)
# Out:
# 2025-11-19 11:32:52,318 - INFO - 🔄 Variações de busca: ['DE ITAPECERICA', 'ITAPECERICA']
# 2025-11-19 11:32:52,319 - INFO - 🔍 Buscando: 'DE ITAPECERICA', Número: '3421'
# 2025-11-19 11:32:52,348 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:52,673 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:52,955 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog    logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  09529  ES DE ITAPECERICA         -23.65679         -46.763502
#
#    distancia_km  similaridade _fonte_busca
# 0         0.095           100        EXATO

# %%
buscar_endereco_com_coordenadas('R. DR ASSIS RIBEIRO',9590,-23.48280242,-46.47076485).head(25)
# Out:
# 2025-11-19 11:32:52,975 - INFO - 🔍 Buscando: 'R. DR ASSIS RIBEIRO', Número: '9590'
# 2025-11-19 11:32:53,010 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:53,223 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog     logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  02429  R DR ASSIS RIBEIRO        -23.483863         -46.468967
#
#    distancia_km  similaridade _fonte_busca
# 0         0.218           100        EXATO

# %%
buscar_endereco_com_coordenadas('AV DR ASSIS RIBEIRO',9590,-23.48280242,-46.47076485).head(25)
# Out:
# 2025-11-19 11:32:53,235 - INFO - 🔍 Buscando: 'AV DR ASSIS RIBEIRO', Número: '9590'
# 2025-11-19 11:32:53,427 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:32:53,448 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:53,835 - INFO - 🔄 Fallback: nenhum resultado do tipo 'AV', mantendo todos os 1 resultados
# 2025-11-19 11:32:53,835 - INFO - 🎯 Fallback: priorizando resultados do tipo 'AV'
# 2025-11-19 11:32:53,835 - INFO - ✅ Fallback sem tipo de via trouxe 1 resultados relevantes
# 2025-11-19 11:32:53,845 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:32:53,849 - INFO - ✅ Resultado final combinado: 1 candidatos
#   codlog     logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  02429  R DR ASSIS RIBEIRO        -23.483863         -46.468967
#
#    distancia_km  similaridade    _fonte_busca
# 1         0.218          90.0  EXATO_SEM_TIPO

# %%
buscar_endereco_com_coordenadas('ESTR LAZARO AMANCIO DE BARROS',284,-23.4669,-46.6947).head(25)
# Out:
# 2025-11-19 11:32:53,860 - INFO - 🔍 Buscando: 'ESTR LAZARO AMANCIO DE BARROS', Número: '284'
# 2025-11-19 11:32:53,905 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:54,136 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog              logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  11665  ES LAZARO AMANCIO DE BARROS        -23.460516         -46.697146
#
#    distancia_km  similaridade _fonte_busca
# 0         0.752           100        EXATO

# %%
buscar_endereco_com_coordenadas('avenida LAZARO AMANCIO DE BARROS',284,-23.4669,-46.6947).head(25)
# Out:
# 2025-11-19 11:32:54,155 - INFO - 🔍 Buscando: 'avenida LAZARO AMANCIO DE BARROS', Número: '284'
# 2025-11-19 11:32:54,268 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:32:54,312 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:32:54,899 - INFO - 🔄 Fallback: nenhum resultado do tipo 'AVENIDA', mantendo todos os 1 resultados
# 2025-11-19 11:32:54,899 - INFO - 🎯 Fallback: priorizando resultados do tipo 'AVENIDA'
# 2025-11-19 11:32:54,899 - INFO - ✅ Fallback sem tipo de via trouxe 1 resultados relevantes
# 2025-11-19 11:32:54,902 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:32:54,905 - INFO - ✅ Resultado final combinado: 1 candidatos
#   codlog              logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  11665  ES LAZARO AMANCIO DE BARROS        -23.460516         -46.697146
#
#    distancia_km  similaridade    _fonte_busca
# 1         0.752          90.0  EXATO_SEM_TIPO

# %%
buscar_endereco_completo('SPEERS',1380,-23.5678529,-46.4581226).head(25)
# Out:
# 2025-11-19 11:32:54,916 - INFO - 🎯 VIA PROBLEMÁTICA DETECTADA: 'SPEERS' - usando APENAS embedding
# 2025-11-19 11:32:54,917 - INFO - 🔍 Executando embedding para: 'SPEERS'
# 2025-11-19 11:32:54,989 - INFO - 📊 Embedding retornou 4 candidatos iniciais
# 2025-11-19 11:32:59,306 - INFO - 🎯 Embedding: 4 resultados válidos processados
# 2025-11-19 11:32:59,306 - INFO - ✅ Embedding para 'SPEERS' trouxe 4 resultados
#   codlog        logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  35942          R JOHN SPEERS        -23.567412         -46.457867
# 2  19860  R DONA VITORIA SPEERS        -23.570758         -46.549630
# 0  18916         R TOMAS SPEERS        -23.517523         -46.594702
# 3  19951       R WILLIAM SPEERS        -23.515980         -46.707231
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB    Distrito_Nome  \
# 1         0.055            80    EMBEDDING  SE  SE3  IQ  PARQUE DO CARMO
# 2         9.332            77    EMBEDDING  SE  SE1  AF     VILA FORMOSA
# 0        15.006            85    EMBEDDING  CN  CN2  MG       VILA MARIA
# 3        26.041            75    EMBEDDING  NO  NO1  LA             LAPA
#
#   Regiao_Nome Classificacao
# 1       Leste      COLETORA
# 2       Leste      COLETORA
# 0       Norte         LOCAL
# 3       Oeste      COLETORA

# %%
buscar_endereco_completo('RUA WILLIAM SPEERS',738,-23.5181108,-46.701804).head(25)
# Out:
# 2025-11-19 11:33:01,793 - INFO - 🔍 Buscando: 'RUA WILLIAM SPEERS', Número: '738'
# 2025-11-19 11:33:01,815 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:33:02,489 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog   logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  19951  R WILLIAM SPEERS        -23.518271         -46.701869         0.019
#
#    similaridade _fonte_busca GET  DET SUB Distrito_Nome Regiao_Nome  \
# 0           100        EXATO  NO  NO1  LA          LAPA       Oeste
#
#   Classificacao
# 0      COLETORA

# %%
buscar_endereco_completo('PONTE DA VILA MARIA',1,-23.5264292,-46.5961179).head(25)
# Out:
# 2025-11-19 11:33:02,699 - INFO - 🔍 Buscando: 'PONTE DA VILA MARIA', Número: '1'
# 2025-11-19 11:33:02,961 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:33:02,963 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:33:02,964 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:33:02,964 - INFO - 🔍 Executando embedding para: 'PONTE DA VILA MARIA'
# 2025-11-19 11:33:03,030 - INFO - 📊 Embedding retornou 6 candidatos iniciais
# 2025-11-19 11:33:06,785 - INFO - 🎯 Embedding: 5 resultados válidos processados
# 2025-11-19 11:33:06,787 - INFO - 🎯 Filtro embedding: 5 resultados relevantes
# 2025-11-19 11:33:06,788 - INFO - ✅ Embedding trouxe 5 resultados relevantes
# 2025-11-19 11:33:06,792 - INFO - ✅ Resultado final combinado: 5 candidatos
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 1  29284  AC A PONTE DE VILA MARIA        -23.526354         -46.596362
# 2  27104    PTE PRES JANIO QUADROS        -23.526161         -46.595836
# 3  69585           R VILA DA PONTE        -23.679209         -46.631729
# 4  23627                R DA PONTE        -23.528041         -46.403488
# 5  33251                 R DA VILA        -23.654415         -46.752096
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB   Distrito_Nome  \
# 1         0.026          76.0    EMBEDDING  MB   TT  MG  VILA GUILHERME
# 2         0.041         100.0    EMBEDDING  MB   TT  MG      VILA MARIA
# 3        17.372          87.0    EMBEDDING  SU  SU3  AD      CID ADEMAR
# 4        19.640          65.0    EMBEDDING  LE  LE2  IT     VILA CURUCA
# 5        21.335          62.0    EMBEDDING  SO  SO3  MB     JD SAO LUIS
#
#   Regiao_Nome Classificacao
# 1       Norte      ARTERIAL
# 2       Norte      ARTERIAL
# 3         Sul      COLETORA
# 4       Leste         LOCAL
# 5         Sul         LOCAL

# %%
buscar_endereco_completo('RUA ROMA',15,-23.5227,-46.6976).head(25)
# Out:
# 2025-11-19 11:33:09,313 - INFO - 🔍 Buscando: 'RUA ROMA', Número: '15'
# 2025-11-19 11:33:09,328 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:33:09,892 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  17348          R ROMA        -23.522843          -46.69672         0.091
#
#    similaridade _fonte_busca GET  DET SUB Distrito_Nome Regiao_Nome  \
# 0           100        EXATO  NO  NO1  LA          LAPA       Oeste
#
#   Classificacao
# 0      COLETORA

# %%
buscar_endereco_completo("ACESSO AVENIDA RADIAL LESTE OESTE",	100,	-23.55652418,	-46.63636798).head(25)
# Out:
# 2025-11-19 11:33:10,246 - INFO - 🔍 Buscando: 'ACESSO AVENIDA RADIAL LESTE OESTE', Número: '100'
# 2025-11-19 11:33:10,246 - INFO - 🎯 Nome de rodovia detectado: 'ACESSO AVENIDA RADIAL LESTE OESTE' - buscando APENAS como rodovia
# 2025-11-19 11:33:10,247 - INFO - ❌ Rodovia 'ACESSO AVENIDA RADIAL LESTE OESTE' não encontrada - não buscando vias urbanas
# 2025-11-19 11:33:10,248 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:33:10,249 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:33:10,249 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:33:10,251 - INFO - 🔍 Executando embedding para: 'ACESSO AVENIDA RADIAL LESTE OESTE'
# 2025-11-19 11:33:10,311 - INFO - 📊 Embedding retornou 16 candidatos iniciais
# 2025-11-19 11:33:18,562 - INFO - 🎯 Embedding: 16 resultados válidos processados
# 2025-11-19 11:33:18,566 - INFO - 🎯 Filtro embedding: 16 resultados relevantes
# 2025-11-19 11:33:18,568 - INFO - 🔄 Fallback: nenhum resultado do tipo 'ACESSO', mantendo todos os 16 resultados
# 2025-11-19 11:33:18,569 - INFO - 🎯 Embedding: priorizando resultados do tipo 'ACESSO'
# 2025-11-19 11:33:18,569 - INFO - ✅ Embedding trouxe 16 resultados relevantes
# 2025-11-19 11:33:18,573 - INFO - ✅ Resultado final combinado: 16 candidatos
#    codlog                        logradouro_PMSP  latitude_geocode  \
# 1   33987             AC A AV RADIAL LESTE OESTE        -23.556550
# 2   00543                   AV ALCANTARA MACHADO        -23.552003
# 3   33667                  AV RADIAL LESTE-OESTE        -23.548178
# 4   42308             AC A AV RADIAL LESTE OESTE        -23.547847
# 5   00544                   VD ALCANTARA MACHADO        -23.552652
# 6   35652  VD PIRES DO RIO - HERMES F FIGUEIREDO        -23.542136
# 7   34122                          R MELO FREIRE        -23.541046
# 8   07645                       AV CD DE FRONTIN        -23.536818
# 9   01702         AV ANTONIO ESTEVAO DE CARVALHO        -23.531711
# 10  53024             PC FRANCISCO SOTO - CHICAO        -23.531798
# 11  12156                        R DR LUIZ AYRES        -23.532120
# 12  Z1615                       TN AGUIA DE HAIA        -23.539803
# 13  49302       R ENG SIDNEY APARECIDO DE MORAES        -23.540117
# 14  49216           AV S.C. CORINTHIANS PAULISTA        -23.543349
# 15  39641                   TN JORN ODON PEREIRA        -23.542488
# 16  22555                AV JOSE PINHEIRO BORGES        -23.540821
#
#     longitude_geocode  distancia_km  similaridade _fonte_busca GET  DET SUB  \
# 1          -46.636770         0.041          99.0    EMBEDDING  CN  SU1  SE
# 2          -46.624116         1.346          81.0    EMBEDDING  LE  LE1  MO
# 3          -46.647216         1.444          92.0    EMBEDDING  CN  CN3  SE
# 4          -46.647610         1.498          99.0    EMBEDDING  OE  CN3  SE
# 5          -46.617955         1.926          81.0    EMBEDDING  LE  LE1  MO
# 6          -46.581028         5.864          81.0    EMBEDDING  MB  LE1  MO
# 7          -46.578027         6.191          81.0    EMBEDDING  LE  LE1  MO
# 8          -46.557186         8.364          81.0    EMBEDDING  LE  LE1  AF
# 9          -46.521771        12.003          81.0    EMBEDDING  LE  LE3  PE
# 10         -46.501474        14.023          81.0    EMBEDDING  LE  LE3  PE
# 11         -46.500613        14.102          81.0    EMBEDDING  LE  LE3  PE
# 12         -46.484798        15.562          81.0    EMBEDDING  LE  LE3  PE
# 13         -46.472574        16.796          81.0    EMBEDDING  LE  LE4  IQ
# 14         -46.471307        16.889          81.0    EMBEDDING  LE  LE4  IQ
# 15         -46.466534        17.382          81.0    EMBEDDING  LE  LE4  IQ
# 16         -46.465007        17.555          81.0    EMBEDDING  LE  LE4  IQ
#
#    Distrito_Nome Regiao_Nome Classificacao
# 1             SE      Centro      COLETORA
# 2           BRAS       Leste      ARTERIAL
# 3      REPUBLICA      Centro           VTR
# 4      REPUBLICA      Centro         LOCAL
# 5           BRAS       Leste      ARTERIAL
# 6          BELEM       Leste      ARTERIAL
# 7        TATUAPE       Leste      ARTERIAL
# 8        TATUAPE       Leste      ARTERIAL
# 9   VILA MATILDE       Leste      ARTERIAL
# 10  VILA MATILDE       Leste      COLETORA
# 11   ARTUR ALVIM       Leste      ARTERIAL
# 12   ARTUR ALVIM       Leste      ARTERIAL
# 13      ITAQUERA       Leste      COLETORA
# 14      ITAQUERA       Leste      ARTERIAL
# 15      ITAQUERA       Leste      ARTERIAL
# 16      ITAQUERA       Leste      ARTERIAL

# %%
buscar_endereco_completo("TRABALHADORES",	100,	-23.55652418,	-46.63636798).head(25)
# Out:
# 2025-11-19 11:33:27,564 - INFO - 🔍 Buscando: 'TRABALHADORES', Número: '100'
# 2025-11-19 11:33:27,595 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:33:28,018 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog       logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  42369  RV DOS TRABALHADORES        -23.477599         -46.500444
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB       Distrito_Nome  \
# 0        16.404           100        EXATO  LE  LE3  EM  ERMELINO MATARAZZO
#
#   Regiao_Nome Classificacao
# 0       Leste          None

# %%
buscar_endereco_completo('COMPLEXO VIARIO AYRTON SENNA',100,-23.5874,-46.665).head(25)
# Out:
# 2025-11-19 11:33:28,394 - INFO - 🔍 Buscando: 'COMPLEXO VIARIO AYRTON SENNA', Número: '100'
# 2025-11-19 11:33:28,395 - INFO - 🎯 Nome de rodovia detectado: 'COMPLEXO VIARIO AYRTON SENNA' - buscando APENAS como rodovia
# 2025-11-19 11:33:28,395 - INFO - ❌ Rodovia 'COMPLEXO VIARIO AYRTON SENNA' não encontrada - não buscando vias urbanas
# 2025-11-19 11:33:28,398 - INFO - 🔄 Resultado principal insuficiente, aplicando fallbacks...
# 2025-11-19 11:33:28,398 - INFO - 🔄 Sem resultados principais - usando embedding
# 2025-11-19 11:33:28,399 - INFO - 🔄 Problema não resolvido, tentando embedding...
# 2025-11-19 11:33:28,399 - INFO - 🔍 Executando embedding para: 'COMPLEXO VIARIO AYRTON SENNA'
# 2025-11-19 11:33:28,454 - INFO - 📊 Embedding retornou 8 candidatos iniciais
# 2025-11-19 11:33:32,647 - INFO - 🎯 Embedding: 8 resultados válidos processados
# 2025-11-19 11:33:32,650 - INFO - 🎯 Filtro embedding: 7 resultados relevantes
# 2025-11-19 11:33:32,651 - INFO - ✅ Embedding trouxe 7 resultados relevantes
# 2025-11-19 11:33:32,655 - INFO - ✅ Resultado final combinado: 7 candidatos
#   codlog                   logradouro_PMSP  latitude_geocode  \
# 1  46726                   CV AYRTON SENNA        -23.591259
# 2  49244                   PC AYRTON SENNA        -23.626987
# 3  51504                 CV NELSON PAULINO        -23.663550
# 4  Z4712       TV AYRTON SENNA (JD M RITA)        -23.715210
# 5  Z1579                    R AYRTON SENNA        -23.479512
# 6  Z2930  R AYRTON SENNA (VILA ROSEIRA II)        -23.562663
# 7  Z4744     R AYRTON SENNA (JD MIRIAM-ZL)        -23.525413
#
#    longitude_geocode  distancia_km  similaridade _fonte_busca GET  DET SUB  \
# 1         -46.651315         1.459         100.0    EMBEDDING  SO  SU2  VM
# 2         -46.720213         7.143          63.0    EMBEDDING  SO  SO2  CL
# 3         -46.728399        10.650          61.0    EMBEDDING  SO  SO3  MB
# 4         -46.677746        14.271          61.0    EMBEDDING  SU  SU3  CS
# 5         -46.494067        21.156          66.0    EMBEDDING  LE  LE3  EM
# 6         -46.393482        27.808          66.0    EMBEDDING  LE  LE4  GU
# 7         -46.387388        29.124          66.0    EMBEDDING  LE  LE4  GU
#
#         Distrito_Nome Regiao_Nome Classificacao
# 1               MOEMA         Sul      ARTERIAL
# 2        VILA ANDRADE         Sul         LOCAL
# 3         JD SAO LUIS         Sul      ARTERIAL
# 4           CID DUTRA         Sul         LOCAL
# 5  ERMELINO MATARAZZO       Leste         LOCAL
# 6          GUAIANASES       Leste      COLETORA
# 7             LAJEADO       Leste         LOCAL

# %%
buscar_endereco_completo('AYRTON SENNA',726,-23.506833,-46.550722).head(25)
# Out:
# 2025-11-19 11:33:37,005 - INFO - 🔍 Buscando: 'AYRTON SENNA', Número: '726'
# 2025-11-19 11:33:37,005 - INFO - 🎯 Nome de rodovia detectado: 'AYRTON SENNA' - buscando APENAS como rodovia
# 2025-11-19 11:33:37,403 - INFO - ✅ Rodovia 'AYRTON SENNA' encontrada: RV DOS TRABALHADORES
# 2025-11-19 11:33:37,403 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog       logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  42369  RV DOS TRABALHADORES        -23.484314         -46.505216
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB Distrito_Nome  \
# 0         5.273           100      RODOVIA  LE  LE3  PE      CANGAIBA
#
#   Regiao_Nome Classificacao
# 0       Leste       RODOVIA

# %%
buscar_endereco_completo('AYRTON SENNA',26,-23.5067867,-46.5453531).head(25)
# Out:
# 2025-11-19 11:33:37,715 - INFO - 🔍 Buscando: 'AYRTON SENNA', Número: '26'
# 2025-11-19 11:33:37,715 - INFO - 🎯 Nome de rodovia detectado: 'AYRTON SENNA' - buscando APENAS como rodovia
# 2025-11-19 11:33:38,015 - INFO - ✅ Rodovia 'AYRTON SENNA' encontrada: RV DOS TRABALHADORES
# 2025-11-19 11:33:38,015 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog       logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  42369  RV DOS TRABALHADORES        -23.476697         -46.499837
#
#    distancia_km  similaridade _fonte_busca GET  DET   SUB Distrito_Nome  \
# 0         5.722           100      RODOVIA  LE  LE3  None          None
#
#   Regiao_Nome Classificacao
# 0        None          None

# %%
buscar_endereco_completo('RUA BAHIA',128,-23.5441643,-46.6596565).head(25)
# Out:
# 2025-11-19 11:33:38,286 - INFO - 🔍 Buscando: 'RUA BAHIA', Número: '128'
# 2025-11-19 11:33:38,325 - INFO - ✅ 8 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:33:43,966 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog           logradouro_PMSP  latitude_geocode  longitude_geocode  \
# 0  02722                   R BAHIA        -23.544137         -46.659527
# 1  Z4716   R BAHIA (JD MARIA RITA)        -23.716105         -46.677667
# 2  Z4363    R BAHIA (JD PAINEIRAS)        -23.435146         -46.810684
# 3  Z1840                   R BAHIA        -23.742041         -46.657493
# 4  Z4765     R BAHIA (JD PANTANAL)        -23.480449         -46.409667
# 5  Z4890  R BAHIA (CID TIRADENTES)        -23.587588         -46.397236
# 6  Z1320      R BAHIA (JD VITORIA)        -23.590003         -46.387876
# 7  Z3620                   R BAHIA        -23.791563         -46.723416
#
#    distancia_km  similaridade _fonte_busca GET  DET SUB   Distrito_Nome  \
# 0         0.014           100        EXATO  OE  OE1  SE      CONSOLACAO
# 1        19.207           100        EXATO  SU  SU3  CS       CID DUTRA
# 2        19.600           100        EXATO  NO  NO3  PR      ANHANGUERA
# 3        22.004           100        EXATO  SU  SU4  CS          GRAJAU
# 4        26.456           100        EXATO  LE  LE2  MP       JD HELENA
# 5        27.179           100        EXATO  LE  LE4  CT  CID TIRADENTES
# 6        28.165           100        EXATO  LE  LE4  CT  CID TIRADENTES
# 7        28.266           100        EXATO  SU  SU4  PA     PARELHEIROS
#
#   Regiao_Nome Classificacao
# 0      Centro      COLETORA
# 1         Sul         LOCAL
# 2       Norte         LOCAL
# 3         Sul         LOCAL
# 4       Leste         LOCAL
# 5       Leste         LOCAL
# 6       Leste         LOCAL
# 7         Sul         LOCAL

# %%
buscar_endereco_completo('ANHANGUERA',4.899,-23.4343,-46.7864).head(25)
# Out:
# 2025-11-19 11:33:50,943 - INFO - 🔍 Buscando: 'ANHANGUERA', Número: '4.899'
# 2025-11-19 11:33:50,943 - INFO - 🎯 Nome de rodovia detectado: 'ANHANGUERA' - buscando APENAS como rodovia
# 2025-11-19 11:33:50,968 - INFO - 🛣️  VIA ANHANGUERA: KM 4.899 → Metro 4899
# 2025-11-19 11:33:52,346 - INFO - ✅ Rodovia 'ANHANGUERA' encontrada: VIA ANHANGUERA
# 2025-11-19 11:33:52,351 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  01429  VIA ANHANGUERA        -23.499518         -46.754852         7.934
#
#    similaridade _fonte_busca GET  DET SUB Distrito_Nome Regiao_Nome  \
# 0           100      RODOVIA  NO  NO3  LA       JAGUARA       Oeste
#
#   Classificacao
# 0       RODOVIA

# %%
buscar_endereco_completo('ANHANGUERA',5,-23.4343,-46.7864).head(25)
# Out:
# 2025-11-19 11:33:52,906 - INFO - 🔍 Buscando: 'ANHANGUERA', Número: '5'
# 2025-11-19 11:33:52,906 - INFO - 🎯 Nome de rodovia detectado: 'ANHANGUERA' - buscando APENAS como rodovia
# 2025-11-19 11:33:52,912 - INFO - 🛣️  VIA ANHANGUERA: KM 5.0 → Metro 5000
# 2025-11-19 11:33:53,694 - INFO - ✅ Rodovia 'ANHANGUERA' encontrada: VIA ANHANGUERA
# 2025-11-19 11:33:53,703 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  01429  VIA ANHANGUERA        -23.499518         -46.754852         7.934
#
#    similaridade _fonte_busca GET  DET SUB Distrito_Nome Regiao_Nome  \
# 0           100      RODOVIA  NO  NO3  LA       JAGUARA       Oeste
#
#   Classificacao
# 0       RODOVIA

# %%
buscar_endereco_completo('TERMINAL METRO TATUAPE  SUL',10,-23.5412,-46.5767).head(25)
# Out:
# 2025-11-19 11:33:54,025 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'TERMINAL METRO TATUAPE  SUL'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('RUA DO GASOMETRO',739,-23.5434,-46.6193).head(25)
# Out:
# 2025-11-19 11:33:54,036 - INFO - 🔍 Buscando: 'RUA DO GASOMETRO', Número: '739'
# 2025-11-19 11:33:54,043 - INFO - ✅ 1 resultado(s) EXATO(s) relevantes
# 2025-11-19 11:33:54,284 - INFO - ✅ Resultado principal considerado SUFICIENTE
#   codlog logradouro_PMSP  latitude_geocode  longitude_geocode  distancia_km  \
# 0  07786  R DO GASOMETRO         -23.54316         -46.618538         0.082
#
#    similaridade _fonte_busca GET  DET SUB Distrito_Nome Regiao_Nome  \
# 0           100        EXATO  LE  LE1  MO          BRAS       Leste
#
#   Classificacao
# 0      COLETORA

# %%
buscar_endereco_completo('METRO PEDRO II',100,-23.5496652,-46.6258742).head(25)
# Out:
# 2025-11-19 11:33:54,885 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'METRO PEDRO II'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('ESTACAO CARRAO',1,-23.5378,-46.5641).head(25)
# Out:
# 2025-11-19 11:33:54,894 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'ESTACAO CARRAO'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('TERMINAL METRO TATUAPE  SUL',10,-23.5412,-46.5767).head(25)
# Out:
# 2025-11-19 11:33:54,901 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'TERMINAL METRO TATUAPE  SUL'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('METRO CONCEICAO',100,-23.635197,-46.6412687).head(25)
# Out:
# 2025-11-19 11:33:54,911 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'METRO CONCEICAO'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('TERMINAL METRO CARRAO SUL',10,-23.5383501,-46.5634522).head(25)
# Out:
# 2025-11-19 11:33:54,925 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'TERMINAL METRO CARRAO SUL'
#   logradouro_PMSP
# 0  NAO ENCONTRADO

# %%
buscar_endereco_completo('ESTAÇÃO METRO CAMPO LIMPO',143,-23.64984785,-46.75936179).head(25)
# Out:
# 2025-11-19 11:33:54,931 - INFO - 🚫 Busca por ponto de transporte bloqueada: 'ESTAÇÃO METRO CAMPO LIMPO'
#   logradouro_PMSP
# 0  NAO ENCONTRADO
