# %%
import logging

logging.disable(logging.INFO)  # desabilita INFO temporariamente

#logging.disable(logging.NOTSET)  # reativa se quiser depois

# %%
import logging

logging.disable(logging.INFO)  # desabilita INFO temporariamente

# ✅ RODANDO de 2015 a 2019
from processamento_resiliente import processar_sinistros_resiliente

# Configurações
PASTA_ENTRADA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO"
PASTA_SAIDA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS"

# ✅ EXECUTAR PROCESSAMENTO RESILIENTE
resultados = processar_sinistros_resiliente(
    arquivos="sinistros_sp_2015_2019.xlsx",
    pasta_entrada=PASTA_ENTRADA,
    pasta_saida=PASTA_SAIDA,
    sufixo="_enriquecido",
    batch_size=5000,
    max_tentativas=3,
    ciclos_maximos=4
)
# Out:
# ⚙️  PROCESSADOR RESILIENTE INICIADO:
#    - Batch size: 5000
#    - Tentativas por ciclo: 3
#    - Ciclos máximos: 4
#    - Espera entre ciclos: 10min
#    - Checkpoints: checkpoints_resilientes
# ✅ Módulos importados com sucesso!
# <h3>🚀 PROCESSAMENTO RESILIENTE: sinistros_sp_2015_2019.xlsx</h3>
# 📊 DADOS CARREGADOS: 32337 registros
# 🔧 PRÉ-PROCESSANDO DADOS...
# ✅ Coordenadas originais preservadas
# ✅ Circunscrição aplicada
# 📦 LOTES CRIADOS: 7 lotes de 5000 registros
#
# 🔄 PROCESSANDO LOTE 1/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 1: 4737✅ 263❌
#
# 🔄 PROCESSANDO LOTE 2/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 2: 4824✅ 176❌
#
# 🔄 PROCESSANDO LOTE 3/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 3: 4804✅ 196❌
#
# 🔄 PROCESSANDO LOTE 4/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 4: 4849✅ 151❌
#
# 🔄 PROCESSANDO LOTE 5/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 5: 4844✅ 156❌
#    💾 Checkpoint salvo: Lote 5
#
# 🔄 PROCESSANDO LOTE 6/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 6: 4851✅ 149❌
#
# 🔄 PROCESSANDO LOTE 7/7...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 7: 2263✅ 74❌
# 🚫 Colunas removidas: ['linha_origem', 'status_processamento', 'motivo_status', 'timestamp_processamento']
# 📊 Colunas restantes: ['id_sinistro', 'logradouro', 'numero_logradouro', 'latitude_original', 'longitude_original', 'latitude_geocode', 'longitude_geocode', 'codlog', 'logradouro_PMSP', 'DET', 'GET', 'SUB', 'Distrito_Nome', 'Regiao_Nome', 'Classificacao', 'similaridade', 'distancia_km', 'fora_circunscricao', '_fonte_busca']
#
# ======================================================================
# 📊 RELATÓRIO RESILIENTE - PROCESSAMENTO EM LOTES
# ======================================================================
# 📁 Arquivo processado: sinistros_sp_2015_2019.xlsx
# 📈 Total de registros: 32,337
# 🎯 Taxa de sucesso: 31,172 (96.4%)
# ⚠️  Falhas/fallbacks: 1,165 (3.6%)
# 📦 Tamanho do lote: 5000
# 🔄 Tentativas por ciclo: 3
# 🔄 Ciclos máximos: 4
#
# 📋 DISTRIBUIÇÃO DE STATUS:
#    • SUCESSO: 31,172 (96.4%)
#    • FALLBACK: 1,165 (3.6%)
#
# 📍 FORA DA CIRCUNSCRIÇÃO: 401 (1.2%)
#
# 💾 ARQUIVO SALVO: X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS\sinistros_sp_2015_2019_enriquecido.xlsx
# ======================================================================
# <div style='color: green'>✅ CONCLUÍDO: sinistros_sp_2015_2019_enriquecido.xlsx</div>
#         <div style='background: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 5px solid #007acc;'>
#             <h3>🎉 PROCESSAMENTO RESILIENTE CONCLUÍDO!</h3>
#             <p><strong>⏱️ Tempo total:</strong> 17:03:39.54</p>
#             <p><strong>📁 Arquivos processados:</strong> 1</p>
#             <p><strong>📊 Configuração:</strong> Lotes de 5000, 3 tentativas por ciclo</p>  <!-- ✅ CORRIGIDO -->
#         </div>

# %%
import logging

logging.disable(logging.INFO)  # desabilita INFO temporariamente

# ✅ RODANDO de 2014 (2 registros)
from processamento_resiliente import processar_sinistros_resiliente

# Configurações
PASTA_ENTRADA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO"
PASTA_SAIDA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS"

# ✅ EXECUTAR PROCESSAMENTO RESILIENTE
resultados = processar_sinistros_resiliente(
    arquivos="sinistros_sp_2014.xlsx",
    pasta_entrada=PASTA_ENTRADA,
    pasta_saida=PASTA_SAIDA,
    sufixo="_enriquecido",
    batch_size=5000,
    max_tentativas=3,
    ciclos_maximos=4
)
# Out:
# ⚙️  PROCESSADOR RESILIENTE INICIADO:
#    - Batch size: 5000
#    - Tentativas por ciclo: 3
#    - Ciclos máximos: 4
#    - Espera entre ciclos: 10min
#    - Checkpoints: checkpoints_resilientes
# ✅ Módulos importados com sucesso!
# <h3>🚀 PROCESSAMENTO RESILIENTE: sinistros_sp_2014.xlsx</h3>
# 📊 DADOS CARREGADOS: 2 registros
# 🔧 PRÉ-PROCESSANDO DADOS...
# ✅ Coordenadas originais preservadas
# ✅ Circunscrição aplicada
# 📦 LOTES CRIADOS: 1 lotes de 5000 registros
#
# 🔄 PROCESSANDO LOTE 1/1...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 1: 2✅ 0❌
# 🚫 Colunas removidas: ['linha_origem', 'status_processamento', 'motivo_status', 'timestamp_processamento']
# 📊 Colunas restantes: ['id_sinistro', 'logradouro', 'numero_logradouro', 'latitude_original', 'longitude_original', 'latitude_geocode', 'longitude_geocode', 'codlog', 'logradouro_PMSP', 'DET', 'GET', 'SUB', 'Distrito_Nome', 'Regiao_Nome', 'Classificacao', 'similaridade', 'distancia_km', 'fora_circunscricao', '_fonte_busca']
#
# ======================================================================
# 📊 RELATÓRIO RESILIENTE - PROCESSAMENTO EM LOTES
# ======================================================================
# 📁 Arquivo processado: sinistros_sp_2014.xlsx
# 📈 Total de registros: 2
# 🎯 Taxa de sucesso: 2 (100.0%)
# ⚠️  Falhas/fallbacks: 0 (0.0%)
# 📦 Tamanho do lote: 5000
# 🔄 Tentativas por ciclo: 3
# 🔄 Ciclos máximos: 4
#
# 📋 DISTRIBUIÇÃO DE STATUS:
#    • SUCESSO: 2 (100.0%)
#
# 📍 FORA DA CIRCUNSCRIÇÃO: 0 (0.0%)
#
# 💾 ARQUIVO SALVO: X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS\sinistros_sp_2014_enriquecido.xlsx
# ======================================================================
# <div style='color: green'>✅ CONCLUÍDO: sinistros_sp_2014_enriquecido.xlsx</div>
#         <div style='background: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 5px solid #007acc;'>
#             <h3>🎉 PROCESSAMENTO RESILIENTE CONCLUÍDO!</h3>
#             <p><strong>⏱️ Tempo total:</strong> 00:00:11.32</p>
#             <p><strong>📁 Arquivos processados:</strong> 1</p>
#             <p><strong>📊 Configuração:</strong> Lotes de 5000, 3 tentativas por ciclo</p>  <!-- ✅ CORRIGIDO -->
#         </div>

# %%
import logging

logging.disable(logging.INFO)  # desabilita INFO temporariamente

# ✅ RODANDO 2020 E 2021
from processamento_resiliente import processar_sinistros_resiliente

# Configurações
PASTA_ENTRADA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO"
PASTA_SAIDA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS"

# ✅ EXECUTAR PROCESSAMENTO RESILIENTE
resultados = processar_sinistros_resiliente(
    arquivos="sinistros_sp_2020_2021.xlsx",
    pasta_entrada=PASTA_ENTRADA,
    pasta_saida=PASTA_SAIDA,
    sufixo="_enriquecido",
    batch_size=5000,
    max_tentativas=3,
    ciclos_maximos=4
)
# Out:
# ⚙️  PROCESSADOR RESILIENTE INICIADO:
#    - Batch size: 5000
#    - Tentativas por ciclo: 3
#    - Ciclos máximos: 4
#    - Espera entre ciclos: 10min
#    - Checkpoints: checkpoints_resilientes
# ✅ Módulos importados com sucesso!
# <h3>🚀 PROCESSAMENTO RESILIENTE: sinistros_sp_2020_2021.xlsx</h3>
# 📊 DADOS CARREGADOS: 54007 registros
# 🔧 PRÉ-PROCESSANDO DADOS...
# ✅ Coordenadas originais preservadas
# ✅ Circunscrição aplicada
# 📦 LOTES CRIADOS: 11 lotes de 5000 registros
#
# 🔄 PROCESSANDO LOTE 1/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 1: 4849✅ 151❌
#
# 🔄 PROCESSANDO LOTE 2/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 2: 4832✅ 168❌
#
# 🔄 PROCESSANDO LOTE 3/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 3: 4880✅ 120❌
#
# 🔄 PROCESSANDO LOTE 4/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 4: 4836✅ 164❌
#
# 🔄 PROCESSANDO LOTE 5/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 5: 4830✅ 170❌
#    💾 Checkpoint salvo: Lote 5
#
# 🔄 PROCESSANDO LOTE 6/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 6: 4812✅ 188❌
#
# 🔄 PROCESSANDO LOTE 7/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 7: 4837✅ 163❌
#
# 🔄 PROCESSANDO LOTE 8/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 8: 4835✅ 165❌
#
# 🔄 PROCESSANDO LOTE 9/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 9: 4844✅ 156❌
#
# 🔄 PROCESSANDO LOTE 10/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 10: 4830✅ 170❌
#    💾 Checkpoint salvo: Lote 10
#
# 🔄 PROCESSANDO LOTE 11/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 11: 3861✅ 146❌
# 🚫 Colunas removidas: ['linha_origem', 'status_processamento', 'motivo_status', 'timestamp_processamento']
# 📊 Colunas restantes: ['id_sinistro', 'logradouro', 'numero_logradouro', 'latitude_original', 'longitude_original', 'latitude_geocode', 'longitude_geocode', 'codlog', 'logradouro_PMSP', 'DET', 'GET', 'SUB', 'Distrito_Nome', 'Regiao_Nome', 'Classificacao', 'similaridade', 'distancia_km', 'fora_circunscricao', '_fonte_busca']
#
# ======================================================================
# 📊 RELATÓRIO RESILIENTE - PROCESSAMENTO EM LOTES
# ======================================================================
# 📁 Arquivo processado: sinistros_sp_2020_2021.xlsx
# 📈 Total de registros: 54,007
# 🎯 Taxa de sucesso: 52,246 (96.7%)
# ⚠️  Falhas/fallbacks: 1,761 (3.3%)
# 📦 Tamanho do lote: 5000
# 🔄 Tentativas por ciclo: 3
# 🔄 Ciclos máximos: 4
#
# 📋 DISTRIBUIÇÃO DE STATUS:
#    • SUCESSO: 52,246 (96.7%)
#    • FALLBACK: 1,761 (3.3%)
#
# 📍 FORA DA CIRCUNSCRIÇÃO: 519 (1.0%)
#
# 💾 ARQUIVO SALVO: X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS\sinistros_sp_2020_2021_enriquecido.xlsx
# ======================================================================
# <div style='color: green'>✅ CONCLUÍDO: sinistros_sp_2020_2021_enriquecido.xlsx</div>
#         <div style='background: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 5px solid #007acc;'>
#             <h3>🎉 PROCESSAMENTO RESILIENTE CONCLUÍDO!</h3>
#             <p><strong>⏱️ Tempo total:</strong> 28:17:16.49</p>
#             <p><strong>📁 Arquivos processados:</strong> 1</p>
#             <p><strong>📊 Configuração:</strong> Lotes de 5000, 3 tentativas por ciclo</p>  <!-- ✅ CORRIGIDO -->
#         </div>

# %%
import logging

logging.disable(logging.INFO)  # desabilita INFO temporariamente

# ✅ RODANDO 2022 E 2023
from processamento_resiliente import processar_sinistros_resiliente

# Configurações
PASTA_ENTRADA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO"
PASTA_SAIDA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS"

# ✅ EXECUTAR PROCESSAMENTO RESILIENTE
resultados = processar_sinistros_resiliente(
    arquivos="sinistros_sp_2022_2023.xlsx",
    pasta_entrada=PASTA_ENTRADA,
    pasta_saida=PASTA_SAIDA,
    sufixo="_enriquecido",
    batch_size=5000,
    max_tentativas=3,
    ciclos_maximos=4
)
# Out:
# ⚙️  PROCESSADOR RESILIENTE INICIADO:
#    - Batch size: 5000
#    - Tentativas por ciclo: 3
#    - Ciclos máximos: 4
#    - Espera entre ciclos: 10min
#    - Checkpoints: checkpoints_resilientes
# ✅ Módulos importados com sucesso!
# <h3>🚀 PROCESSAMENTO RESILIENTE: sinistros_sp_2022_2023.xlsx</h3>
# 📊 DADOS CARREGADOS: 58847 registros
# 🔧 PRÉ-PROCESSANDO DADOS...
# ✅ Coordenadas originais preservadas
# ✅ Circunscrição aplicada
# 📦 LOTES CRIADOS: 12 lotes de 5000 registros
#
# 🔄 PROCESSANDO LOTE 1/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 1: 4833✅ 167❌
#
# 🔄 PROCESSANDO LOTE 2/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 2: 4842✅ 158❌
#
# 🔄 PROCESSANDO LOTE 3/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 3: 4836✅ 164❌
#
# 🔄 PROCESSANDO LOTE 4/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 4: 4820✅ 180❌
#
# 🔄 PROCESSANDO LOTE 5/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 5: 4856✅ 144❌
#    💾 Checkpoint salvo: Lote 5
#
# 🔄 PROCESSANDO LOTE 6/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 6: 4847✅ 153❌
#
# 🔄 PROCESSANDO LOTE 7/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 7: 4834✅ 166❌
#
# 🔄 PROCESSANDO LOTE 8/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 8: 4813✅ 187❌
#
# 🔄 PROCESSANDO LOTE 9/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 9: 4807✅ 193❌
#
# 🔄 PROCESSANDO LOTE 10/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 10: 4830✅ 170❌
#    💾 Checkpoint salvo: Lote 10
#
# 🔄 PROCESSANDO LOTE 11/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 11: 4881✅ 119❌
#
# 🔄 PROCESSANDO LOTE 12/12...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 12: 3774✅ 73❌
# 🚫 Colunas removidas: ['linha_origem', 'status_processamento', 'motivo_status', 'timestamp_processamento']
# 📊 Colunas restantes: ['id_sinistro', 'logradouro', 'numero_logradouro', 'latitude_original', 'longitude_original', 'latitude_geocode', 'longitude_geocode', 'codlog', 'logradouro_PMSP', 'DET', 'GET', 'SUB', 'Distrito_Nome', 'Regiao_Nome', 'Classificacao', 'similaridade', 'distancia_km', 'fora_circunscricao', '_fonte_busca']
#
# ======================================================================
# 📊 RELATÓRIO RESILIENTE - PROCESSAMENTO EM LOTES
# ======================================================================
# 📁 Arquivo processado: sinistros_sp_2022_2023.xlsx
# 📈 Total de registros: 58,847
# 🎯 Taxa de sucesso: 56,973 (96.8%)
# ⚠️  Falhas/fallbacks: 1,874 (3.2%)
# 📦 Tamanho do lote: 5000
# 🔄 Tentativas por ciclo: 3
# 🔄 Ciclos máximos: 4
#
# 📋 DISTRIBUIÇÃO DE STATUS:
#    • SUCESSO: 56,973 (96.8%)
#    • FALLBACK: 1,874 (3.2%)
#
# 📍 FORA DA CIRCUNSCRIÇÃO: 702 (1.2%)
#
# 💾 ARQUIVO SALVO: X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS\sinistros_sp_2022_2023_enriquecido.xlsx
# ======================================================================
# <div style='color: green'>✅ CONCLUÍDO: sinistros_sp_2022_2023_enriquecido.xlsx</div>
#         <div style='background: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 5px solid #007acc;'>
#             <h3>🎉 PROCESSAMENTO RESILIENTE CONCLUÍDO!</h3>
#             <p><strong>⏱️ Tempo total:</strong> 31:52:23.72</p>
#             <p><strong>📁 Arquivos processados:</strong> 1</p>
#             <p><strong>📊 Configuração:</strong> Lotes de 5000, 3 tentativas por ciclo</p>  <!-- ✅ CORRIGIDO -->
#         </div>

# %%
# ✅ RODANDO 2024 E 2025 ATÉ 31/10 =======RODANDO ESSE AQUI===========
from processamento_resiliente import processar_sinistros_resiliente

# Configurações
PASTA_ENTRADA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO"
PASTA_SAIDA = r"X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS"

# ✅ EXECUTAR PROCESSAMENTO RESILIENTE
resultados = processar_sinistros_resiliente(
    arquivos="sinistros_sp_2024_2025.xlsx",
    pasta_entrada=PASTA_ENTRADA,
    pasta_saida=PASTA_SAIDA,
    sufixo="_enriquecido",
    batch_size=5000,
    max_tentativas=3,
    ciclos_maximos=4
)
# Out:
# ⚙️  PROCESSADOR RESILIENTE INICIADO:
#    - Batch size: 5000
#    - Tentativas por ciclo: 3
#    - Ciclos máximos: 4
#    - Espera entre ciclos: 10min
#    - Checkpoints: checkpoints_resilientes
# ✅ Módulos importados com sucesso!
# <h3>🚀 PROCESSAMENTO RESILIENTE: sinistros_sp_2024_2025.xlsx</h3>
# 📊 DADOS CARREGADOS: 52264 registros
# 🔧 PRÉ-PROCESSANDO DADOS...
# ✅ Coordenadas originais preservadas
# ✅ Circunscrição aplicada
# 📦 LOTES CRIADOS: 11 lotes de 5000 registros
#
# 🔄 PROCESSANDO LOTE 1/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 1: 4926✅ 74❌
#
# 🔄 PROCESSANDO LOTE 2/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 2: 4911✅ 89❌
#
# 🔄 PROCESSANDO LOTE 3/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 3: 4932✅ 68❌
#
# 🔄 PROCESSANDO LOTE 4/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 4: 4919✅ 81❌
#
# 🔄 PROCESSANDO LOTE 5/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 5: 4915✅ 85❌
#    💾 Checkpoint salvo: Lote 5
#
# 🔄 PROCESSANDO LOTE 6/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 6: 4920✅ 80❌
#
# 🔄 PROCESSANDO LOTE 7/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 7: 4925✅ 75❌
#
# 🔄 PROCESSANDO LOTE 8/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 8: 4920✅ 80❌
#
# 🔄 PROCESSANDO LOTE 9/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 9: 4914✅ 86❌
#
# 🔄 PROCESSANDO LOTE 10/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 10: 4907✅ 93❌
#    💾 Checkpoint salvo: Lote 10
#
# 🔄 PROCESSANDO LOTE 11/11...
#    🎯 Ciclo 1, Tentativa 1...
#    ✅ Lote 11: 2223✅ 41❌
# 🚫 Colunas removidas: ['linha_origem', 'status_processamento', 'motivo_status', 'timestamp_processamento']
# 📊 Colunas restantes: ['id_sinistro', 'logradouro', 'numero_logradouro', 'latitude_original', 'longitude_original', 'latitude_geocode', 'longitude_geocode', 'codlog', 'logradouro_PMSP', 'DET', 'GET', 'SUB', 'Distrito_Nome', 'Regiao_Nome', 'Classificacao', 'similaridade', 'distancia_km', 'fora_circunscricao', '_fonte_busca']
#
# ======================================================================
# 📊 RELATÓRIO RESILIENTE - PROCESSAMENTO EM LOTES
# ======================================================================
# 📁 Arquivo processado: sinistros_sp_2024_2025.xlsx
# 📈 Total de registros: 52,264
# 🎯 Taxa de sucesso: 51,412 (98.4%)
# ⚠️  Falhas/fallbacks: 852 (1.6%)
# 📦 Tamanho do lote: 5000
# 🔄 Tentativas por ciclo: 3
# 🔄 Ciclos máximos: 4
#
# 📋 DISTRIBUIÇÃO DE STATUS:
#    • SUCESSO: 51,412 (98.4%)
#    • FALLBACK: 852 (1.6%)
#
# 📍 FORA DA CIRCUNSCRIÇÃO: 879 (1.7%)
#
# 💾 ARQUIVO SALVO: X:\Dados\ARQUIVO DE CÓDIGOS\Modulos_de_tratamento_de_dados\Arquivos_de_teste\ARQUIVOS_DE_HOMOLOGACAO\DADOS_ENRIQUECIDOS\sinistros_sp_2024_2025_enriquecido.xlsx
# ======================================================================
# <div style='color: green'>✅ CONCLUÍDO: sinistros_sp_2024_2025_enriquecido.xlsx</div>
#         <div style='background: #f0f8ff; padding: 15px; border-radius: 10px; border-left: 5px solid #007acc;'>
#             <h3>🎉 PROCESSAMENTO RESILIENTE CONCLUÍDO!</h3>
#             <p><strong>⏱️ Tempo total:</strong> 30:22:55.94</p>
#             <p><strong>📁 Arquivos processados:</strong> 1</p>
#             <p><strong>📊 Configuração:</strong> Lotes de 5000, 3 tentativas por ciclo</p>  <!-- ✅ CORRIGIDO -->
#         </div>

# %% [markdown]
# # Dados Horários de atividade de processa,emtp
#
# ### Início de Processamento:
#
# - 2025-11-28 14:29:36 | PROCESSAMENTO INICIADO
# - 2025-11-28 14:30:29 | PROCESSAMENTO INICIADO
# - 2025-11-28 14:30:39 | PROCESSAMENTO INICIADO
# - 2025-11-28 14:30:46 | PROCESSAMENTO INICIADO
#
# ### Sistema de persistência em blocos:
# - 2025-11-28 12:18:30 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 14:21:19 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 14:27:05 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 17:18:10 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 17:19:00 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 17:21:17 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 17:23:54 | Lote 1 | Tentativa 1 | SUCESSO
# - 2025-11-28 19:47:30 | Lote 2 | Tentativa 1 | SUCESSO
# - 2025-11-28 19:52:04 | Lote 2 | Tentativa 1 | SUCESSO
# - 2025-11-28 20:02:01 | Lote 2 | Tentativa 1 | SUCESSO
# - 2025-11-28 20:05:33 | Lote 2 | Tentativa 1 | SUCESSO
# - 2025-11-28 22:06:14 | Lote 3 | Tentativa 1 | SUCESSO
# - 2025-11-28 22:12:43 | Lote 3 | Tentativa 1 | SUCESSO
# - 2025-11-28 22:29:31 | Lote 3 | Tentativa 1 | SUCESSO
# - 2025-11-28 22:44:36 | Lote 3 | Tentativa 1 | SUCESSO
# - 2025-11-29 00:23:44 | Lote 4 | Tentativa 1 | SUCESSO
# - 2025-11-29 00:39:17 | Lote 4 | Tentativa 1 | SUCESSO
# - 2025-11-29 00:53:32 | Lote 4 | Tentativa 1 | SUCESSO
# - 2025-11-29 01:18:13 | Lote 4 | Tentativa 1 | SUCESSO
# - 2025-11-29 02:46:04 | Lote 5 | Tentativa 1 | SUCESSO
# - 2025-11-29 03:05:52 | Lote 5 | Tentativa 1 | SUCESSO
# - 2025-11-29 03:25:42 | Lote 5 | Tentativa 1 | SUCESSO
# - 2025-11-29 04:02:02 | Lote 5 | Tentativa 1 | SUCESSO
# - 2025-11-29 05:23:04 | Lote 6 | Tentativa 1 | SUCESSO
# - 2025-11-29 05:51:54 | Lote 6 | Tentativa 1 | SUCESSO
# - 2025-11-29 06:15:42 | Lote 6 | Tentativa 1 | SUCESSO
# - 2025-11-29 06:57:39 | Lote 6 | Tentativa 1 | SUCESSO
# - 2025-11-29 07:33:56 | Lote 7 | Tentativa 1 | SUCESSO
# - 2025-11-29 08:09:57 | Lote 7 | Tentativa 1 | SUCESSO
# - 2025-11-29 08:39:32 | Lote 7 | Tentativa 1 | SUCESSO
# - 2025-11-29 10:10:46 | Lote 7 | Tentativa 1 | SUCESSO
# - 2025-11-29 11:01:42 | Lote 8 | Tentativa 1 | SUCESSO
# - 2025-11-29 11:32:51 | Lote 8 | Tentativa 1 | SUCESSO
# - 2025-11-29 13:21:08 | Lote 8 | Tentativa 1 | SUCESSO
# - 2025-11-29 13:45:33 | Lote 9 | Tentativa 1 | SUCESSO
# - 2025-11-29 14:19:24 | Lote 9 | Tentativa 1 | SUCESSO
# - 2025-11-29 16:23:44 | Lote 9 | Tentativa 1 | SUCESSO
# - 2025-11-29 16:32:23 | Lote 10 | Tentativa 1 | SUCESSO
# - 2025-11-29 17:15:52 | Lote 10 | Tentativa 1 | SUCESSO
# - 2025-11-29 18:47:41 | Lote 11 | Tentativa 1 | SUCESSO
# - 2025-11-29 19:31:20 | Lote 10 | Tentativa 1 | SUCESSO
# - 2025-11-29 20:07:26 | Lote 11 | Tentativa 1 | SUCESSO
# - 2025-11-29 20:50:43 | Lote 11 | Tentativa 1 | SUCESSO
# - 2025-11-29 22:22:40 | Lote 12 | Tentativa 1 | SUCESSO
